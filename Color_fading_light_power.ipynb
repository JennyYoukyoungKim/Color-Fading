# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\jenny.kim-es\Downloads\Confidence_interval.csv")

print(df)
# Out:
#     CFL  Power
# 0    10   0.27
# 1    20   0.54
# 2    30   0.81
# 3    40   1.09
# 4    50   1.34
# 5    60   1.62
# 6    70   1.90
# 7    80   2.17
# 8    90   2.46
# 9   100   2.75
# 10   10   0.28
# 11   20   0.55
# 12   30   0.82
# 13   40   1.10
# 14   50   1.35
# 15   60   1.63
# 16   70   1.90
# 17   80   2.18
# 18   90   2.47
# 19  100   2.75

# %%
import seaborn as sns
import numpy as np

#sns.regplot(data=df, x="CFL", y="Power", ci=90)

from scipy.stats import pearsonr

r1, pvalue = pearsonr((df['CFL']), df['Power'])
r2 = r1 *r1
g=sns.regplot(data=df, x='CFL', y='Power', ci=90, label=f'R^2 = {r2:.5f}')
g.legend()
